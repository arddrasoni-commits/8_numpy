# %% [markdown]
# <a href="https://colab.research.google.com/github/arddrasoni-commits/8_numpy/blob/main/Experiment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 8
# ## Name: Arddra Soni
# ## PRN: 25070123022
# ## Branch: ENTC
# ## Div. : A1
# ### Application of Numpy in EDA

# %%
import numpy as np

a = np.array ([10,20,30,40])
b = np.array([1,2,3],[4,5,6])
print(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1403494311.py in <cell line: 0>()
#       2
#       3 a = np.array ([10,20,30,40])
# ----> 4 b = np.array([1,2,3],[4,5,6])
#       5 print(a)
#       6 print(b)
#
# TypeError: Field elements must be 2- or 3-tuples, got '4'

# %%
a.ndim
# Out:
# 1

# %%
b.ndim

# %%
a.shape
# Out:
# (4,)

# %%
a.dtype
# Out:
# dtype('int64')

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((3,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
a + 2
# Out:
# array([12, 22, 32, 42])

# %%
a+5
# Out:
# array([15, 25, 35, 45])

# %%
a*2
# Out:
# array([20, 40, 60, 80])

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
np.median(a)
#  when mean and median is the same, data is perfect, therefore there is not "outlier"
# (a data point that differs significantly from the rest of the observations in a dataset,
# appearing as an unusually high or low value)
# Out:
# np.float64(25.0)

# %%
np.max(a)
# Out:
# np.int64(40)

# %%
np.min(a)
# Out:
# np.int64(10)

# %%
np.sum(a)
# Out:
# np.int64(100)

# %%
# Introduction to Pandas
